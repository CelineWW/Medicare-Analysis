# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
file_path = Path("Resources/health_medicare_2016.csv")
df = pd.read_csv(file_path)
df
# Out:
#       Unnamed: 0  State FIPS Code  County FIPS Code  5-digit FIPS Code  \
# 0              0                1                 1               1001
# 1              1                1                 3               1003
# 2              2                1                 5               1005
# 3              3                1                 7               1007
# 4              4                1                 9               1009
# ...          ...              ...               ...                ...
# 3152        3152               56                37              56037
# 3153        3153               56                39              56039
# 3154        3154               56                41              56041
# 3155        3155               56                43              56043
# 3156        3156               56                45              56045
#
#      State Abbreviation COUNTY_NAME  Premature death  Poor or fair health  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# State FIPS Code          0
# County FIPS Code         0
# 5-digit FIPS Code        0
# State Abbreviation       0
#                       ...
# Avg_Risk_Score_AGDU    198
# Person_Years_AGDU      198
# Per_Capita_Exp_AGND    160
# Avg_Risk_Score_AGND    160
# Person_Years_AGND      160
# Length: 83, dtype: int64

# %%
print(*df.columns)
# Out:
# Unnamed: 0 State FIPS Code County FIPS Code 5-digit FIPS Code State Abbreviation COUNTY_NAME Premature death Poor or fair health Poor physical health days Poor mental health days Low birthweight Adult smoking Adult obesity Food environment index Physical inactivity Access to exercise opportunities Excessive drinking Alcohol-impaired driving deaths Sexually transmitted infections Teen births Uninsured Primary care physicians Dentists Mental health providers Preventable hospital stays Diabetes monitoring Mammography screening High school graduation Some colleg Unemployment Children in poverty Income inequality Children in single-parent households Social associations Violent crim Injury deaths Air pollution - particulate matt Drinking water violations Severe housing problems Driving alone to work Long commute - driving alon Premature age-adjusted mortality Child mortality Infant mortality Diabetes prevalenc HIV prevalenc Food insecurity Limited access to healthy foods Drug poisoning dea
# ...

# %%
charac = ['Premature death', 'Poor or fair health', 'Poor physical health days',
       'Poor mental health days', 'Low birthweight', 'Adult smoking',
       'Adult obesity', 'Food environment index', 'Physical inactivity',
       'Access to exercise opportunities', 'Excessive drinking',
       'Alcohol-impaired driving deaths', 'Sexually transmitted infections',
       'Teen births', 'Uninsured', 'Primary care physicians', 'Dentists',
       'Mental health providers', 'Preventable hospital stays',
       'Diabetes monitoring', 'Mammography screening',
       'High school graduation', 'Some colleg', 'Unemployment',
       'Children in poverty', 'Income inequality',
       'Children in single-parent households', 'Social associations',
       'Violent crim', 'Injury deaths', 'Air pollution - particulate matt',
       'Drinking water violations', 'Severe housing problems',
       'Driving alone to work', 'Long commute - driving alon',
       'Premature age-adjusted mortality', 'Child mortality',
       'Infant mortality', 'Diabetes prevalenc', 'HIV prevalenc',
       'Food insecurity', 'Limited access to healthy foods',
       'Drug poisoning deaths', 'Motor vehicle crash deaths',
       'Uninsured adults', 'Uninsured children', 'Health care costs',
       'Other primary care providers', 'Could not see doctor due to cost',
       'Median household incom', 'Children eligible for free lunch',
       'Homicides', 'Population', '% below 18 years of ag', '% 65 and old',
       '% Non-Hispanic African American', '% American Indian and Alaskan Nati',
       '% Asian', '% Native Hawaiian/Other Pacific Island', '% Hispanic',
       '% Non-Hispanic whit', '% not proficient in English', '% Females',
       '% R']

# %%
print(*zip(df.columns, df[charac].isnull().sum()))
# Out:
# ('Unnamed: 0', 69) ('State FIPS Code', 400) ('County FIPS Code', 334) ('5-digit FIPS Code', 552) ('State Abbreviation', 99) ('COUNTY_NAME', 430) ('Premature death', 0) ('Poor or fair health', 0) ('Poor physical health days', 0) ('Poor mental health days', 13) ('Low birthweight', 916) ('Adult smoking', 24) ('Adult obesity', 182) ('Food environment index', 101) ('Physical inactivity', 1) ('Access to exercise opportunities', 139) ('Excessive drinking', 82) ('Alcohol-impaired driving deaths', 335) ('Sexually transmitted infections', 152) ('Teen births', 50) ('Uninsured', 93) ('Primary care physicians', 469) ('Dentists', 0) ('Mental health providers', 1) ('Preventable hospital stays', 1) ('Diabetes monitoring', 0) ('Mammography screening', 1) ('High school graduation', 0) ('Some colleg', 167) ('Unemployment', 121) ('Children in poverty', 33) ('Income inequality', 59) ('Children in single-parent households', 0) ('Social associations', 0) ('Violent crim', 0) ('Injury deaths', 69) ('Air poll
# ...
